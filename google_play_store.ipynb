# %% [markdown]
# Dataset: https://www.kaggle.com/datasets/lava18/google-play-store-apps

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv ("C:\\Users\\Administrator\\Desktop\\projects from pc\\googleplaystore.csv")

# %% [markdown]
# 1. Display the first 5 rows of the dataset

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %% [markdown]
# 2. Display the last 5 rows of the dataset

# %%
df.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# ...

# %% [markdown]
# 3. Getting information about dataset (no. of rows and the no. of the columns)

# %%
print('the number of rows : ',df.shape[0])
print('the number of columns : ',df.shape[1])
# Out:
# the number of rows :  10841
# the number of columns :  13

# %% [markdown]
# 4. Drop Dublicates

# %%
df.drop_duplicates()
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# 5. Get information about dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# 6. Get the overall statistics of the dataset

# %%
df.describe(include="all")
# Out:
#            App Category       Rating Reviews                Size    Installs  \
# count    10841    10841  9367.000000   10841               10841       10841
# unique    9660       34          NaN    6002                 462          22
# top     ROBLOX   FAMILY          NaN       0  Varies with device  1,000,000+
# freq         9     1972          NaN     596                1695        1579
# mean       NaN      NaN     4.193338     NaN                 NaN         NaN
# std        NaN      NaN     0.537431     NaN                 NaN         NaN
# min        NaN      NaN     1.000000     NaN                 NaN         NaN
# 25%        NaN      NaN     4.000000     NaN                 NaN         NaN
# 50%        NaN      NaN     4.300000     NaN                 NaN         NaN
# 75%        NaN      NaN     4.500000     NaN                 NaN         NaN
# max        NaN      NaN    19.000000     NaN                 NaN         NaN
#
# ...

# %% [markdown]
# 7. Total no. of App titles contain Astrology

# %%
df['App'].str.contains('Astrology',case=False).sum()
# Out:
# 3

# %% [markdown]
# 8. Find the Average Rating

# %%
df['Rating'].mean()
# Out:
# 4.193338315362443

# %%
df['Rating'].describe()
# Out:
# count    9367.000000
# mean        4.193338
# std         0.537431
# min         1.000000
# 25%         4.000000
# 50%         4.300000
# 75%         4.500000
# max        19.000000
# Name: Rating, dtype: float64

# %%
df['Rating'].plot(kind='box', figsize=(5,5))
# Out:
# <Axes: >

# %% [markdown]
# 9. Find The Total no. of unique category

# %%
df['Category'].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION',
#        '1.9'], dtype=object)

# %%
len(df['Category'].unique())
# Out:
# 34

# %% [markdown]
# 10. Which category gets the highest average rating

# %%
df[df['Rating']> df['Rating'].mean()]['Category'].value_counts()
df.groupby('Category')['Rating'].mean()[1:].sort_values(ascending=False).round(2)
# Out:
# Category
# EVENTS                 4.44
# EDUCATION              4.39
# ART_AND_DESIGN         4.36
# BOOKS_AND_REFERENCE    4.35
# PERSONALIZATION        4.34
# PARENTING              4.30
# GAME                   4.29
# BEAUTY                 4.28
# HEALTH_AND_FITNESS     4.28
# SHOPPING               4.26
# SOCIAL                 4.26
# WEATHER                4.24
# SPORTS                 4.22
# PRODUCTIVITY           4.21
# HOUSE_AND_HOME         4.20
# FAMILY                 4.19
# PHOTOGRAPHY            4.19
# AUTO_AND_VEHICLES      4.19
# MEDICAL                4.19
# LIBRARIES_AND_DEMO     4.18
# FOOD_AND_DRINK         4.17
# COMMUNICATION          4.16
# COMICS                 4.16
# NEWS_AND_MAGAZINES     4.13
# FINANCE                4.13
# ENTERTAINMENT          4.13
# BUSINESS               4.12
# TRAVEL_AND_LOCAL       4.11
# LIFESTYLE              4.09
# VIDEO_PLAYERS          4.06
# MAPS_AND_NAVIGATION    4.05
# TOOLS                  4.05
# ...

# %% [markdown]
# 11. Find Total numbers of app having 5 star rating

# %%
df[df['Rating']>=5]['App'].count()
# Out:
# 275

# %% [markdown]
# 12. Find the average value of reviews

# %%
df['Reviews'].replace('3.0M',3.0,inplace=True)

# %%
df['Reviews'] = df['Reviews'].astype(float)

# %%
df['Reviews'].mean()
# Out:
# 444111.9265750392

# %% [markdown]
# 13. Find the total number of free and paid apps

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df.drop(index=10472,inplace=True)
df['Type'].value_counts()
# Out:
# Type
# Free    10039
# Paid      800
# Name: count, dtype: int64

# %% [markdown]
# 14. Which app has the highest reviews

# %%
df.sort_values(by='Reviews',ascending=False).head(1)
# Out:
#            App Category  Rating     Reviews                Size  \
# 2544  Facebook   SOCIAL     4.1  78158306.0  Varies with device
#
#             Installs  Type Price Content Rating  Genres    Last Updated  \
# 2544  1,000,000,000+  Free     0           Teen  Social  August 3, 2018
#
#              Current Ver         Android Ver
# 2544  Varies with device  Varies with device

# %% [markdown]
# 15. top 15 apps from reviews

# %%
df.sort_values(by='Reviews',ascending=False).head(15)
# Out:
#                                            App       Category  Rating  \
# 2544                                  Facebook         SOCIAL     4.1
# 3943                                  Facebook         SOCIAL     4.1
# 381                         WhatsApp Messenger  COMMUNICATION     4.4
# 336                         WhatsApp Messenger  COMMUNICATION     4.4
# 3904                        WhatsApp Messenger  COMMUNICATION     4.4
# 2604                                 Instagram         SOCIAL     4.5
# 2611                                 Instagram         SOCIAL     4.5
# 2545                                 Instagram         SOCIAL     4.5
# 3909                                 Instagram         SOCIAL     4.5
# 382   Messenger – Text and Video Chat for Free  COMMUNICATION     4.0
# 4104  Messenger – Text and Video Chat for Free  COMMUNICATION     4.0
# 335   Messenger – Text and Video Chat for Free  COMMUNICATION     4.0
# ...

# %% [markdown]
# 16. Find the average ratings for free and paid apps

# %%
df.groupby('Type')['Rating'].mean()
# Out:
# Type
# Free    4.186203
# Paid    4.266615
# Name: Rating, dtype: float64

# %%
df['Installs1'] = df['Installs'].str.replace(',','')
df['Installs1'] = df['Installs1'].str.replace('+','')
df['Installs1'] = df['Installs1'].astype('int')
df.sort_values(by='Installs1',ascending=False).head()
# Out:
#                                            App       Category  Rating  \
# 3896                            Subway Surfers           GAME     4.5
# 3943                                  Facebook         SOCIAL     4.1
# 335   Messenger – Text and Video Chat for Free  COMMUNICATION     4.0
# 3523                              Google Drive   PRODUCTIVITY     4.4
# 3565                              Google Drive   PRODUCTIVITY     4.4
#
#          Reviews                Size        Installs  Type Price  \
# 3896  27711703.0                 76M  1,000,000,000+  Free     0
# 3943  78128208.0  Varies with device  1,000,000,000+  Free     0
# 335   56642847.0  Varies with device  1,000,000,000+  Free     0
# 3523   2731211.0  Varies with device  1,000,000,000+  Free     0
# 3565   2731211.0  Varies with device  1,000,000,000+  Free     0
#
#      Content Rating         Genres    Last Updated         Current Ver  \
# 3896   Everyone 10+         Arcade   July 12, 2018              1.90.0
# ...
